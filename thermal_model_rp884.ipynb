# %%
import numpy as np
from io import StringIO

# %%
import pandas as pd
from pandas import DataFrame as df
data = pd.read_csv('45_EXL.csv',sep=',',header=6)

# %%
data
# Out:
#      BLCODE  SUB AGE  SEX  YEAR  DAY  TIME  ASH  PRXY_TSA TSA    ...     \
# 0         1   11   .    1  1991   98  1140  0.0         2   .    ...
# 1         1    4   .    1  1991   98  1149 -2.0         1   .    ...
# 2         1   27   .    1  1991   98  1205  2.0         1   .    ...
# 3         1   28   .    1  1991   98  1216  0.0         2   .    ...
# 4         1   30   .    0  1991   98  1233  0.4         2   .    ...
# 5         1   23   .    1  1991   98  1246 -0.5         2   .    ...
# 6         1    5   .    1  1991   98  1315  2.0         1   .    ...
# 7         1   13   .    0  1991   98  1418  0.0         2   .    ...
# 8         1    7   .    0  1991   98  1433 -2.0         1   .    ...
# 9         1    8   .    0  1991   98  1442  2.0         1   .    ...
# 10        1   15   .    1  1991   98  1453  1.5         2   .    ...
# 11        1   22   .    0  1991   98  1516  0.0         2   .    ...
# 12        1   24   .    0  1991   98  1526  0.0         2   .    ...
# ...
