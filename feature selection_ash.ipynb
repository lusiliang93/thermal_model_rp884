# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA, KernelPCA
from sklearn.feature_selection import SelectFromModel
from sklearn import preprocessing
from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, cross_val_score
# testing
from sklearn.model_selection import cross_val_predict
from sklearn import metrics
# plot
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
#data_new = pd.read_csv('raw_new.csv', sep=',',engine='python')
data_new = pd.read_csv('raw.csv', sep=',',engine='python')
x = data_new[['TAAV','INSUL','RH','dayav_ta','dayav_rh','MET','TRAV','VELAV']]
y = data_new['ASH']
y = np.round(y)
lab_enc = preprocessing.LabelEncoder()
encoded = lab_enc.fit_transform(y)
np.shape(y)
# Out:
# (5776,)

# %%
pca = PCA(n_components=2)
x_pca = pca.fit_transform(x)
xx = pd.DataFrame(x_pca,columns= ['PC-1','PC-2'])
clf = RandomForestClassifier(n_estimators=50, max_depth = 3, random_state=0)
pipe = Pipeline(steps=[('pca', pca), ('randomforest', clf)])
lab_enc = preprocessing.LabelEncoder()
encoded = lab_enc.fit_transform(y)
cross_val_score(pipe, X=xx, y=encoded, cv=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-e44c548e736f> in <module>()
#       1 pca = PCA(n_components=2)
# ----> 2 x_pca = pca.fit_transform(x)
#       3 xx = pd.DataFrame(x_pca,columns= ['PC-1','PC-2'])
#       4 clf = RandomForestClassifier(n_estimators=50, max_depth = 3, random_state=0)
#       5 pipe = Pipeline(steps=[('pca', pca), ('randomforest', clf)])
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/decomposition/pca.py in fit_transform(self, X, y)
#     357
#     358         """
# --> 359         U, S, V = self._fit(X)
#     360         U = U[:, :self.n_components_]
#     361
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/decomposition/pca.py in _fit(self, X)
#     379
#     380         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 381                         copy=self.copy)
#     382
#     383         # Handle n_components==None
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     566         if force_all_finite:
#     567             _assert_all_finite(array,
# --> 568                                allow_nan=force_all_finite == 'allow-nan')
#     569
#     570     shape_repr = _shape_repr(array.shape)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
# evaluation
predicted = cross_val_predict(clf, x.copy(), encoded, cv=5)
metrics.accuracy_score(encoded, predicted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-70b693ff01bd> in <module>()
#       1 # evaluation
# ----> 2 predicted = cross_val_predict(clf, x.copy(), encoded, cv=5)
#       3 metrics.accuracy_score(encoded, predicted)
#
# NameError: name 'clf' is not defined

# %%
forest = ExtraTreesClassifier(n_estimators=250,
                              random_state=0)
forest.fit(x, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(x.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# %%
data_new = pd.read_csv('lili_feature.csv', sep=',',engine='python')
x = data_new[['temperature','humidity','clo','skin']]
y = data_new['sensation']

# %%
forest = ExtraTreesClassifier(n_estimators=250,
                              random_state=0)
forest.fit(x, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(x.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# %%
x0 = x.iloc[np.where(y==0)][['TAAV','INSUL','RH']]
x3 = x.iloc[np.where(y<0)][['TAAV','INSUL','RH']]
xn3 = x.iloc[np.where(y>0)][['TAAV','INSUL','RH']]
print(len(x0))
print(len(x3))
print(len(xn3))
# Out:
# 2782
# 1337
# 1511

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
#ax = fig.add_subplot(111)
#ax.scatter(x0['TAAV'],x0['RH'], x0['INSUL'],c='purple', marker='o',s=10)
#ax.scatter(x3['TAAV'],x3['RH'], x3['INSUL'],c='b', marker='^',s=10)
ax.scatter(xn3['TAAV'],xn3['RH'], xn3['INSUL'],c='r', marker='^',s=10)
ax.set_xlabel('indoor air temperature')
ax.set_ylabel('relative humidity')
ax.set_zlabel('clothing insulation')
# Out:
# Text(0.5, 0, 'clothing insulation')
